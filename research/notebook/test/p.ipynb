# %%
import pypsa

# %%
n = pypsa.examples.scigrid_de(from_master=True)
n.storage_units.at["100_220kV Pumped Hydro", "p_nom_extendable"] = True
n.storage_units.at["100_220kV Pumped Hydro", "marginal_cost"] = 0
n.storage_units.at["100_220kV Pumped Hydro", "cyclic_state_of_charge"] = True

# %%
n.optimize()

# %%
n.storage_units.loc["100_220kV Pumped Hydro"]

# %%
n.storage_units
